# %% [markdown]
# ## Importation of libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# from keras.preprocessing.text import one_hot
# from keras.preprocessing.text import text_to_word_sequence

# %% [markdown]
# ## Data Visualization And Encoding

# %%
# Load the datasets

fname_train = "data/finnish-task1-train"
fname_test = "data/finnish-task1-test"
fname_dev = "data/finnish-task1-dev"

train = np.loadtxt(fname_train,dtype = str)
test = np.loadtxt(fname_test,dtype = str)
dev = np.loadtxt(fname_dev,dtype = str)

# %%
print(train)
print(train.shape)
# Out:
# [['Ã¤Ã¤kkÃ¶stÃ¤Ã¤' 'pos=V,polar=POS,mood=IMP,tense=PRS,per=3,num=SG'
#   'Ã¤Ã¤kkÃ¶stÃ¤kÃ¶Ã¶n']
#  ['Ã¤Ã¤kkÃ¶stÃ¤Ã¤' 'pos=V,voice=ACT,aspect=PROSP'
#   'Ã¤Ã¤kkÃ¶stÃ¤mÃ¤isillÃ¤Ã¤n']
#  ['aalloittaisuus' 'pos=N,case=ON+ESS,num=PL' 'aalloittaisuuksilla']
#  ...
#  ['zoonoosi' 'pos=N,case=PRIV,num=SG' 'zoonoositta']
#  ['zsaari' 'pos=N,case=IN+LAT,num=PL' 'zsaareihin']
#  ['zumbata' 'pos=V,polar=POS,mood=POT,tense=PRS,per=2,num=PL'
#   'zumbannette']]
# (12693, 3)

# %%
print(test)
print(test.shape)
# Out:
# [['alkeiskoppi' 'pos=N,case=NOM,num=SG' 'alkeiskoppi']
#  ['lenkkitossut' 'pos=N,case=ON+ESS,num=PL' 'lenkkitossuilla']
#  ['baritonitorvi' 'pos=N,case=PRIV,num=SG' 'baritonitorvetta']
#  ...
#  ['katkeroida' 'pos=V,polar=POS,mood=IND,tense=PRS,per=3,num=SG'
#   'katkeroi']
#  ['paarmalintu' 'pos=N,case=TRANS,num=PL' 'paarmalinnuiksi']
#  ['malisiÃ¶Ã¶si' 'pos=ADJ,case=IN+ABL,num=SG' 'malisiÃ¶Ã¶sistÃ¤']]
# (23633, 3)

# %%
print(dev)
print(dev.shape)
# Out:
# [['aakkosto' 'pos=N,case=NOM,num=PL' 'aakkostot']
#  ['aallottaa' 'pos=V,mood=PURP,voice=ACT' 'aallottaakseen']
#  ['aaltoluku' 'pos=N,case=FRML,num=SG' 'aaltolukuna']
#  ...
#  ['ystÃ¤vÃ¤piiri' 'pos=N,case=ON+ABL,num=SG' 'ystÃ¤vÃ¤piiriltÃ¤']
#  ['ytimekÃ¤s' 'pos=ADJ,case=ACC,num=SG' 'ytimekkÃ¤Ã¤n']
#  ['zombi' 'pos=N,case=IN+ABL,num=PL' 'zombeista']]
# (1598, 3)

# %%
## Definition of encoding functions

# Return the dictionary for a given list
def list_to_dict(data):  
    dic = {}
    for x in data:
        dic[x] = dic.get(x, len(dic))
    return dic

# Return the encoded array
def encode(data):
    dics = []
    for i in range(data.shape[1]):
        dic = list_to_dict(data[:,i])
        dics.append(dic)
        for j in range(len(data[:,i])):
            data[:,i][j] = dic[data[:,i][j]]
            
    return data,dics

# %%
train,dics_train = encode(train)
test,dics_test = encode(test)
dev,dics_dev = encode(dev)

# %%
x_train = train[:,0:2]
x_test = test[:,0:2]
x_dev = dev[:,0:2]

y_train = train[:,2]
y_test = test[:,2]
y_dev = dev[:,2]

# %%
print(x_train)
print(x_train.shape)
# Out:
# [['0' '0']
#  ['0' '1']
#  ['1' '2']
#  ...
#  ['9853' '21']
#  ['9854' '24']
#  ['9855' '43']]
# (12693, 2)

# %%
print(y_train)
print(y_train.shape)
# Out:
# ['0' '1' '2' ... '12675' '12676' '12677']
# (12693,)

# %%
print(dics_train[0]) # Display the encoding dictionary used for first column, we store it to do the decoding operation
# Out:
# {'Ã¤Ã¤kkÃ¶stÃ¤Ã¤': 0, 'aalloittaisuus': 1, 'aallokas': 2, 'aalloppi': 3, 'aaltoilla': 4, 'aaltomuoto': 5, 'aaltopelti': 6, 'aaltopituus': 7, 'aalto': 8, 'aaltosulkumerkki': 9, 'aamiaishetki': 10, 'aamiaistaa': 11, 'aamuhetki': 12, 'aamukahvi': 13, 'aamuntorkku': 14, 'aamupuku': 15, 'aamurusko': 16, 'aamutorkku': 17, 'aamutossu': 18, 'Ã¤Ã¤nekÃ¤s': 19, 'Ã¤Ã¤nennopeus': 20, 'Ã¤Ã¤nestyskoppi': 21, 'Ã¤Ã¤nettÃ¶myys': 22, 'Ã¤Ã¤nilevystÃ¶': 23, 'Ã¤Ã¤nioikeus': 24, 'Ã¤Ã¤nittÃ¤Ã¤': 25, 'Ã¤Ã¤nivalli': 26, 'Ã¤Ã¤nnÃ¤htÃ¤Ã¤': 27, 'Ã¤Ã¤nnellÃ¤': 28, 'Ã¤Ã¤ntÃ¶': 29, 'aaprotti': 30, 'Ã¤Ã¤rellisyys': 31, 'Ã¤Ã¤rivasemmisto': 32, 'aarni': 33, 'aarporata': 34, 'aarrelÃ¶ytÃ¶': 35, 'aasianjokipÃ¤Ã¤sky': 36, 'aasiankilpikierto': 37, 'aasiankiuru': 38, 'aasianmarmorimurri': 39, 'aasiansieppokerttu': 40, 'aasiantÃ¶rmÃ¤pÃ¤Ã¤sky': 41, 'aasianuuttukyyhky': 42, 'aasianvuoripeippo': 43, 'aasinmaksaruoho': 44, 'aasi': 45, 'aataminpuku': 46, 'aatelisarvo': 47, 'aatelisneito': 48, 'aatelissuku': 49, 'aatella': 50, 'aaterikkaus': 51, 'aateveli': 52, 'aatto': 53, 'aavesÃ¤rky': 54, 'aavikkogundi': 55, 'aavikkokerttu': 56, 'aavikkotylli': 57, 'aavikkounikeko': 58, 'aavikoittaa': 59, 'aavistuslÃ¤htÃ¶': 60, 'abaloni': 61, 'abatasepti': 62, 'abatsi': 63, 'abbotinsukeltaja-antilooppi': 64, 'abdikoida': 65, 'abdominaali': 66, 'abduktoida': 67, 'abessiniangenetti': 68, 'abhaasi': 69, 'abikopihti': 70, 'abi': 71, 'abolitionismi': 72, 'aboriginaali': 73, 'abortti': 74, 'absintti': 75, 'absolutisti': 76, 'absoluutti': 77, 'absoluuttisuus': 78, 'absorptiospektri': 79, 'abstrahointi': 80, 'abstraktistaa': 81, 'abstraktistua': 82, 'adamantaani': 83, 'adaptoida': 84, 'addukti': 85, 'adeniitti': 86, 'adenoblasti': 87, 'adenohypofyysi': 88, 'adenomyomatoosi': 89, 'adenosiinimonofosfaatti': 90, 'adenosiini': 91, 'adenosyytti': 92, 'adenotonsilliitti': 93, 'adenylaattideaminaasi': 94, 'adenyylisyklaasi': 95, 'aderinsukeltaja-antilooppi': 96, 'adherentti': 97, 'adiadokokineesi': 98, 'adipolyysi': 99, 'adiponitriili': 100, 'adjektiiviattribuutti': 101, 'adjektiivi': 102, 'adjektiivisuus': 103, 'adjuvanttihoito': 104, 'adneksiitti': 105, 'adoptioÃ¤iti': 106, 'adoptoida': 107, 'adoptointi': 108, 'adrenokortikotropiini': 109, 'adrenokromi': 110, 'adrenomedulliini': 111, 'adsorbentti': 112, 'adsorboida': 113, 'adsorbointi': 114, 'adsorboitua': 115, 'adstringentti': 116, 'adulaari': 117, 'adventismi': 118, 'adventisti': 119, 'adventti': 120, 'adverbiaali': 121, 'adverbiaalisuus': 122, 'adverbi': 123, 'adversatiivisuus': 124, 'aerobicata': 125, 'aeromekaniikka': 126, 'aero-otiitti': 127, 'aerosinuiitti': 128, 'aerosoli': 129, 'aerosolipurkki': 130, 'Ã¤estÃ¤Ã¤': 131, 'afÃ¤Ã¤ri': 132, 'affektilabiilisuus': 133, 'affekti': 134, 'affisioida': 135, 'aforismi': 136, 'aforisti': 137, 'afrikandi': 138, 'afrikanmanaatti': 139, 'afrikanmarabu': 140, 'afrikanmerikarhu': 141, 'afrikantylli': 142, 'agenttipartisiippi': 143, 'agglomeraatti': 144, 'agglutinoida': 145, 'aggregaatti': 146, 'aggregointi': 147, 'agitoida': 148, 'ahaggarinkivitamaani': 149, 'ahavoida': 150, 'ahavoittaa': 151, 'ahdettu': 152, 'ahdistaa': 153, 'ahdistella': 154, 'ahdistuneisuus': 155, 'Ã¤hitellÃ¤': 156, 'ahjo': 157, 'Ã¤hkiÃ¤': 158, 'Ã¤hkyÃ¤': 159, 'ahmaista': 160, 'ahnas': 161, 'ahnaus': 162, 'ahneus': 163, 'ahonoidanlukko': 164, 'ahtautua': 165, 'ahto': 166, 'ahtoutua': 167, 'aidata': 168, 'Ã¤idillisyys': 169, 'Ã¤idinÃ¤iti': 170, 'aientaa': 171, 'aihepiiri': 172, 'aiheutua': 173, 'aihki': 174, 'Ã¤iji': 175, 'aikaisheteisyys': 176, 'aikaistua': 177, 'aikakauslehti': 178, 'aikasarja-analyysi': 179, 'Ã¤ikÃ¤tatti': 180, 'aikataulu': 181, 'aikauttaa': 182, 'aikoa': 183, 'aikuistua': 184, 'aikuisuus': 185, 'ailahdella': 186, 'Ã¤imistellÃ¤': 187, 'Ã¤imistyttÃ¤Ã¤': 188, 'aineellistaa': 189, 'aineellistua': 190, 'aineistua': 191, 'ainuntaa': 192, 'airo': 193, 'aistihavainto': 194, 'aitajuoksu': 195, 'Ã¤itelyys': 196, 'Ã¤itiys': 197, 'aitosypressi': 198, 'aivastaa': 199, 'aivoinfarkti': 200, 'aivomato': 201, 'aivopestÃ¤': 202, 'aivosir ...
