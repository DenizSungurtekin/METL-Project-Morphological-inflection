# %% [markdown]
# ## Importation of libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Model,Sequential
from keras.layers import Input, LSTM, Dense, SimpleRNN, Embedding
from tensorflow.keras.utils import to_categorical
import copy as c

# Input() is used to instantiate a Keras tensor.
# Dense implements the operation: output = activation(dot(input, kernel) + bias) 
# LSTM : Seq to Seq model 
# Model groups layers into an object with training and inference features 

# from keras.preprocessing.text import one_hot
# from keras.preprocessing.text import text_to_word_sequence
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Data Visualization And Encoding

# %%
# Load the datasets

fname_train = "data/finnish-task1-train"
fname_test = "data/finnish-task1-test"
fname_dev = "data/finnish-task1-dev"

dataset_train = np.loadtxt(fname_train,dtype = str)
dataset_test = np.loadtxt(fname_test,dtype = str)
dataset_dev = np.loadtxt(fname_dev,dtype = str)

# %%
print(dataset_train)
print(dataset_train.shape)

# print(np.where(dataset_ttrain == 'Ã¤Ã¤kkÃ¶stÃ¤Ã¤' )[0])
# Out:
# [['Ã¤Ã¤kkÃ¶stÃ¤Ã¤' 'pos=V,polar=POS,mood=IMP,tense=PRS,per=3,num=SG'
#   'Ã¤Ã¤kkÃ¶stÃ¤kÃ¶Ã¶n']
#  ['Ã¤Ã¤kkÃ¶stÃ¤Ã¤' 'pos=V,voice=ACT,aspect=PROSP'
#   'Ã¤Ã¤kkÃ¶stÃ¤mÃ¤isillÃ¤Ã¤n']
#  ['aalloittaisuus' 'pos=N,case=ON+ESS,num=PL' 'aalloittaisuuksilla']
#  ...
#  ['zoonoosi' 'pos=N,case=PRIV,num=SG' 'zoonoositta']
#  ['zsaari' 'pos=N,case=IN+LAT,num=PL' 'zsaareihin']
#  ['zumbata' 'pos=V,polar=POS,mood=POT,tense=PRS,per=2,num=PL'
#   'zumbannette']]
# (12693, 3)

# %%
print(dataset_test)
print(dataset_test.shape)
# print(np.where(test == 'Ã¤Ã¤kkÃ¶stÃ¤Ã¤' )[0])
# print(test[21533])
# Out:
# [['alkeiskoppi' 'pos=N,case=NOM,num=SG' 'alkeiskoppi']
#  ['lenkkitossut' 'pos=N,case=ON+ESS,num=PL' 'lenkkitossuilla']
#  ['baritonitorvi' 'pos=N,case=PRIV,num=SG' 'baritonitorvetta']
#  ...
#  ['katkeroida' 'pos=V,polar=POS,mood=IND,tense=PRS,per=3,num=SG'
#   'katkeroi']
#  ['paarmalintu' 'pos=N,case=TRANS,num=PL' 'paarmalinnuiksi']
#  ['malisiÃ¶Ã¶si' 'pos=ADJ,case=IN+ABL,num=SG' 'malisiÃ¶Ã¶sistÃ¤']]
# (23633, 3)

# %%
print(dataset_dev)
print(dataset_dev.shape)
# Out:
# [['aakkosto' 'pos=N,case=NOM,num=PL' 'aakkostot']
#  ['aallottaa' 'pos=V,mood=PURP,voice=ACT' 'aallottaakseen']
#  ['aaltoluku' 'pos=N,case=FRML,num=SG' 'aaltolukuna']
#  ...
#  ['ystÃ¤vÃ¤piiri' 'pos=N,case=ON+ABL,num=SG' 'ystÃ¤vÃ¤piiriltÃ¤']
#  ['ytimekÃ¤s' 'pos=ADJ,case=ACC,num=SG' 'ytimekkÃ¤Ã¤n']
#  ['zombi' 'pos=N,case=IN+ABL,num=PL' 'zombeista']]
# (1598, 3)

# %%
## Definition of encoding functions

# Return the dictionary for a given list
def list_to_dict(data):  
    dic = {}
    for x in data:
        dic[x] = dic.get(x, len(dic))
    return dic

# Return the encoded array
def encode(data):
    dics = []
    for i in range(data.shape[1]):
        dic = list_to_dict(data[:,i])
        dics.append(dic)
        for j in range(len(data[:,i])):
            data[:,i][j] = dic[data[:,i][j]]
            
    return data.astype(np.int),dics

# def concatenate(data):
#     return np.transpose(np.asarray([np.core.defchararray.add(data[:,0], data[:,1]),data[:,0]]))

# %%
# Encoding 
train,dics_train = encode(dataset_train) 
# test,dics_test = encode(dataset_ttest)
# dev,dics_dev = encode(dataset_tdev)

# %%
print(train)
print(train.shape)
# Out:
# [[    0     0     0]
#  [    0     1     1]
#  [    1     2     2]
#  ...
#  [ 9853    21 12675]
#  [ 9854    24 12676]
#  [ 9855    43 12677]]
# (12693, 3)

# %%
x_train = train[:,0:2]
y_train = train[:,2]

# %%
print(x_train)
print(x_train.shape)
# Out:
# [[   0    0]
#  [   0    1]
#  [   1    2]
#  ...
#  [9853   21]
#  [9854   24]
#  [9855   43]]
# (12693, 2)

# %%
print(y_train)
print(y_train.shape)
# Out:
# [    0     1     2 ... 12675 12676 12677]
# (12693,)

# %% [markdown]
# **Whenever we’re working with categorical data, we don’t want to leave it as integers because the model will interpreted the samples with a higher number as having more significance. to_categorical is quick and dirty way of encoding the data.**

# %%
# x_train = to_categorical(train)
# x_test = to_categorical(test)
# x_dev = to_categorical(dev)

# y_train = to_categorical(train)
# y_test = to_categorical(test)
# y_dev = to_categorical(dev)

# print(x_train)

# %%
# Define meta-parameter

epochs = 30
batch_size = 500

# %%
# Update the encoding dictionaries (word-context-target)

def update_dics(data,dics):
    new_dics = []
    for i in range((data.shape[1])):
        dic = dics[i]
        for el in data[:,i]:
            if el not in list(dic.keys()): 
                dic[el] = max(list(dic.values())) + 1 # add word to dictionary
                
        new_dics.append(dic)
        
    return new_dics

# Encode data with given dictionarries

def encode_with_dict(data,dics):
    copy = c.deepcopy(data)
    for i in range((data.shape[1])):
        dic = dics[i]
        copy[:,i] = np.asarray([dic[el] for el in data[:,i]]) 
    return copy.astype(np.int)

# %%
# Update dictionarry
dics = update_dics(dataset_test,dics_train)
dics = update_dics(dataset_dev,dics)

# %%
print(len(y_train)+len(y_test)+len(y_dev))
# Out:
# 37924

# %%
print(len(dics[-1]))
# Out:
# 37851

# %%
print(dataset_test[:,2][2])
# Out:
# baritonitorvetta

# %%
for i in range(len(dataset_train)):
    print(np.where(dataset_train[:,2] == dataset_test[:,2][i]))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# ...
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
# Encoding test and dev
test = encode_with_dict(dataset_test,dics)
dev = encode_with_dict(dataset_dev,dics)

# %%
print(test[0])
# Out:
# [  289    19 12678]

# %%
print(dics[0])

# %%
print(get_key(12678,dics[2]))
# Out:
# alkeiskoppi

# %%
print(dataset_test[0][2])
# Out:
# alkeiskoppi

# %%
print(test)
# Out:
# [[  289    19 12678]
#  [ 9856     2 12679]
#  [ 9857    21 12680]
#  ...
#  [ 3365    35 36272]
#  [18939    41 36273]
#  [14794    88 36274]]

# %%
print(dev)
# Out:
# [[17980     9 36275]
#  [11854    59 36276]
#  [10927    37 36277]
#  ...
#  [19296    14 37848]
#  [ 9841    48 37849]
#  [19297    18 37850]]

# %%
x_test = test[:,0:2]
x_dev = dev[:,0:2]
y_test = test[:,2]
y_dev = dev[:,2]

# %%
max_words = len(list(dics[0].keys()))    # size of vocabulary
max_len =  len(list(dics[-1].keys()))    # lenght of input sequence

# %%
print(x_test)
# Out:
# [[  289    19]
#  [ 9856     2]
#  [ 9857    21]
#  ...
#  [ 3365    35]
#  [18939    41]
#  [14794    88]]

# %%
model_lstm = Sequential()

# %%
model_lstm.add(Embedding(input_dim = max_words, output_dim = 100,input_length = 2))
# model_lstm.add(SpatialDropout1D(0.3))
model_lstm.add(LSTM(100)) #dropout = 0.3,recurrent_dropout = 0.3
model_lstm.add(Dense(100, activation = 'relu'))
# model_lstm.add(Dropout(0.3))
model_lstm.add(Dense(max_len, activation = 'softmax'))

# %%
model_lstm.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='Adam',
    metrics=['accuracy']
)

# %%
history = model_lstm.fit(
    x_train,
    y_train,
    epochs = epochs,
    batch_size = batch_size
)
# Out:
# c:\users\dede\appdata\local\programs\python\python38\lib\site-packages\tensorflow\python\framework\indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# Epoch 1/30
# 12693/12693 [==============================] - 6s 509us/step - loss: 10.5432 - accuracy: 0.0000e+00
# Epoch 2/30
# 12693/12693 [==============================] - 6s 461us/step - loss: 10.5209 - accuracy: 7.8784e-05
# Epoch 3/30
# 12693/12693 [==============================] - 6s 471us/step - loss: 10.4185 - accuracy: 0.0000e+00
# Epoch 4/30
# 12693/12693 [==============================] - 6s 463us/step - loss: 9.8881 - accuracy: 7.8784e-05
# Epoch 5/30
# 12693/12693 [==============================] - 6s 458us/step - loss: 9.5888 - accuracy: 0.0000e+00
# Epoch 6/30
# 12693/12693 [==============================] - 6s 457us/step - loss: 9.4070 - accuracy: 7.8784e-05
# Epoch 7/30
# 12693/12693 [==============================] - 6s 461us/step - loss: 9.0800 - accuracy: 3.1513e-04
# Epoch 8/30
# 12693/12693 [==============================] - 6s 459us/step - loss: 8.6017 - accuracy: 2.3635e-04
# Epoch 9/30
# 12693/12693 [==============================] - 6s 457us/step - loss: 8.0148 - accuracy: 6.3027e-04
# Epoch 10/30
# 12693/12693 [==============================] - 6s 454us/step - loss: 7.4102 - accuracy: 0.0017
# Epoch 11/30
# 12693/12693 [==============================] - 6s 464us/step - loss: 6.8456 - accuracy: 0.0040
# Epoch 12/30
# 12693/12693 [==============================] - 6s 459us/step - loss: 6.3635 - accuracy: 0.0068
# Epoch 13/30
# 12693/12693 [==============================] - 6s 459us/step - loss: 5.9428 - accuracy: 0.0143
# Epoch 14/30
# 12693/12693 [==============================] - 6s 462us/step - loss: 5.5553 - accuracy: 0.0251
# Epoch 15/30
# 12693/12693 [==============================] - 6s 458us/step - loss: 5.2013 - accuracy: 0.0376
# Epoch 16/30
# 12693/12693 [==============================] - 6s 459us/step - loss: 4.8545 - accuracy: 0.0552
# Epoch 17/30
# 12693/12693 [==============================] - 6s 461us/step - loss: 4.5097 - accuracy: 0.0808
# Epoch 18/30
# 12693/12693 [==============================] - 6s 461us/step - loss: 4.1802 - accuracy: 0.1063
# Epoch 19/30
# 12693/12693 [==============================] - 6s 466us/step - loss: 3.8627 - accuracy: 0.1394
# Epoch 20/30
# 12693/12693 [==============================] - 6s 458us/step - loss: 3.5551 - accuracy: 0.1825
# Epoch 21/30
# 12693/12693 [==============================] - 6s 458us/step - loss: 3.2598 - accuracy: 0.2293
# Epoch 22/30
# 12693/12693 [==============================] - 6s 458us/step - loss: 2.9754 - accuracy: 0.2839
# Epoch 23/30
# 12693/12693 [==============================] - 6s 457us/step - loss: 2.6902 - accuracy: 0.3483
# Epoch 24/30
# 12693/12693 [==============================] - 6s 463us/step - loss: 2.4227 - accuracy: 0.4000
# Epoch 25/30
# 12693/12693 [==============================] - 6s 464us/step - loss: 2.1668 - accuracy: 0.4684
# Epoch 26/30
# 12693/12693 [==============================] - 6s 467us/step - loss: 1.9027 - accuracy: 0.5457
# Epoch 27/30
# 12693/12693 [==============================] - 6s 458us/step - loss: 1.6602 - accuracy: 0.6035
# Epoch 28/30
# 12693/12693 [==============================] - 6s 462us/step - loss: 1.4311 - accuracy: 0.6742
# Epoch 29/30
# 12693/12693 [==============================] - 6s 459us/step - loss: 1.2130 - accuracy: 0.7361
# Epoch 30/30
# 12693/12693 [==============================] - 6s 469us/step - loss: 1.0256 - accuracy: 0.7937

# %%
def prediction(data,size = 20):
    return np.argmax(model_lstm.predict(data[:size]),axis = 1)


# function to return key for any value
def get_key(val,my_dict):
    for key, value in my_dict.items():
         if val == value:
             return key
    return "key doesn't exist"

# Return words by specifing the index and the dictionary -> decoding
def return_pred(y_pred_index,dic):
    return np.asarray([get_key(index,dic) for index in y_pred_index])

def acc(y_pred,y):
    return np.sum(y == y_pred)/len(y)

# %%
# Decoding and Compute train accuracy 

size = 100
dic_x_train1 = dics[0]
dic_y_train1 = dics[-1]
y_pred_index_train1 = prediction(x_train,size)
y_pred_train1 = return_pred(y_pred_index_train1,dic_y_train1)
y_train1 = return_pred(y_train,dic_y_train1)[:size]

print("Training acuracy: ",acc(y_pred_train1,y_train1))
# Out:
# Training acuracy:  0.93

# %%
# plt.clf()
# loss = history.history['loss']
# val_loss = history.history['val_loss']
# epochs = range(1, len(loss) + 1)
# plt.plot(epochs, loss, 'g', label='Training loss')
# plt.plot(epochs, val_loss, 'y', label='Validation loss')
# plt.title('Training and validation loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
print(dataset_test[:,0][:20])
print(y_pred_test[:20])
# Out:
# ['alkeiskoppi' 'lenkkitossut' 'baritonitorvi' 'tahmautua' 'sivistyÃ¤'
#  'efedriini' 'vÃ¤littÃ¤Ã¤' 'vesilintu' 'Ã¤Ã¤rivasemmisto' 'farmaritakki'
#  'goijata' 'skitso' 'iglu' 'puolipallo' 'sÃ¤Ã¤nnÃ¶ttÃ¶myys' 'roiskua'
#  'oksentaa' 'aurinkouuni' 'ovovivipaarisuus' 'nuuskata']
# ['kiehautettua' 'ekotyypeillÃ¤' 'koleerisuudetta' 'shamponoinemme'
#  'kiksauttakaamme' 'linnunmaidoissa' 'pilkatkaamme' 'kefalosporiinille'
#  'rantsut' 'hÃ¶yrypitoisuuksien' 'pullistit' 'munapusseiksi'
#  'koleerisuudetta' 'oirekirjolle' 'pateettisuudelle' 'puserru'
#  'kapuloisin' 'kerskaile' 'ahdetuille' 'kÃ¤Ã¤nnellen']

# %%
print(len(x_train))
print(len(x_dev))
# Out:
# 12693
# 1598

# %%
print(np.where(dataset_train == "alkeiskoppi"))
print(dataset_train[378])
# Out:
# (array([378], dtype=int64), array([0], dtype=int64))
# ['alkeiskoppi' 'pos=N,case=IN+ABL,num=SG' 'alkeiskopista']

# %%
print(np.where(dataset_test == "alkeiskoppi"))
print(dataset_test[0])
# Out:
# (array([0, 0], dtype=int64), array([0, 2], dtype=int64))
# ['alkeiskoppi' 'pos=N,case=NOM,num=SG' 'alkeiskoppi']

# %%
print(y_test[500:600])
# Out:
# [13178 13179 13180 13181 13182 13183 13184 13185 13186 13187 13188 13189
#  13190 13191 13192 13193 13194 13195 13196 13197 13198 13199 13200 13201
#  13202 13203 13204 13205 13206 13207 13208 13209 13210 13211 13212 13213
#  13214 13215 13216 13217 13218 13219 13220 13221 13222 13223 13224 13225
#  13226 13227 13228 13229 13230 13231 13232 13233 13234 13235 13236 13237
#  13238 13239 13240 13241 13242 13243 13244 13245 13246 13247 13248 13249
#  13250 13251 13252 13253 13254 13255 13256 13257 13258 13259 13260 13261
#  13262 13263 13264 13265 13266 13267 13268 13269 13270 13271 13272 13273
#  13274 13275 13276 13277]

# %%
# Decoding and Compute test accuracy 

size = len(y_test)
dic_x_test = dics[0]
dic_y_test = dics[-1]
y_pred_index_test = prediction(x_test,size)
y_pred_test = return_pred(y_pred_index_test,dic_y_test)
y_test1 = return_pred(y_test,dic_y_test)[:size]

print("Test acuracy: ",acc(y_pred_test,y_test1))
# Out:
# Test acuracy:  0.0

# %%
print(y_pred_test)
# Out:
# ['kiehautettua' 'ekotyypeillÃ¤' 'koleerisuudetta' ... 'ajattelee'
#  'adverbeiksi' 'mobiileihin']

# %%
print(y_test1)
# Out:
# ['alkeiskoppi' 'lenkkitossuilla' 'baritonitorvetta' ... 'katkeroi'
#  'paarmalinnuiksi' 'malisiÃ¶Ã¶sistÃ¤']

# %%
print(dataset_test[0:20])
# Out:
# [['alkeiskoppi' 'pos=N,case=NOM,num=SG' 'alkeiskoppi']
#  ['lenkkitossut' 'pos=N,case=ON+ESS,num=PL' 'lenkkitossuilla']
#  ['baritonitorvi' 'pos=N,case=PRIV,num=SG' 'baritonitorvetta']
#  ['tahmautua' 'pos=V,polar=POS,mood=POT,tense=PRS,per=1,num=PL'
#   'tahmautunemme']
#  ['sivistyÃ¤' 'pos=V,polar=POS,mood=IMP,tense=PRS,per=1,num=PL'
#   'sivistykÃ¤Ã¤mme']
#  ['efedriini' 'pos=N,case=IN+ESS,num=PL' 'efedriineissÃ¤']
#  ['vÃ¤littÃ¤Ã¤' 'pos=V,polar=POS,mood=COND,tense=PRS,voice=PASS'
#   'vÃ¤litettÃ¤isiin']
#  ['vesilintu' 'pos=N,case=ON+ALL,num=SG' 'vesilinnulle']
#  ['Ã¤Ã¤rivasemmisto' 'pos=N,case=NOM,num=PL' 'Ã¤Ã¤rivasemmistot']
#  ['farmaritakki' 'pos=N,case=GEN,num=PL' 'farmaritakkien']
#  ['goijata' 'pos=V,polar=POS,mood=IND,tense=PST,per=2,num=SG' 'goijasit']
#  ['skitso' 'pos=N,case=ACC,num=PL' 'skitsot']
#  ['iglu' 'pos=N,case=PRIV,num=SG' 'iglutta']
#  ['puolipallo' 'pos=N,case=ON+ALL,num=SG' 'puolipallolle']
#  ['sÃ¤Ã¤nnÃ¶ttÃ¶myys' 'pos=N,case=ON+ALL,num=SG' 'sÃ¤Ã¤nnÃ¶ttÃ¶myydelle']
#  ['roiskua' 'pos=V,polar=POS,mood=COND,tense=PRS,per=2,num=SG'
#   'roiskuisit']
#  ['oksentaa' 'pos=V,polar=POS,mood=COND,tense=PRS,per=3,num=SG'
#   'oksentaisi']
#  ['aurinkouuni' 'pos=N,case=ACC,num=SG' 'aurinkouunin']
#  ['ovovivipaarisuus' 'pos=ADJ,case=ON+ALL,num=PL' 'ovovivipaarisuuksille']
#  ['nuuskata' 'pos=V,polar=POS,mood=POT,tense=PRS,per=1,num=SG'
#   'nuuskannen']]

# %%
print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-421157ec4fd7> in <module>
# ----> 1 print(y_pred)
#
# NameError: name 'y_pred' is not defined

# %%
print(y.tolist().count("key doesn't exist"))
# Out:
# 0

# %%
print(len(y))
# Out:
# 20
